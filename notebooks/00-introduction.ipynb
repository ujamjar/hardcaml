# %% [markdown]
# # HardCaml

# %% [markdown]
# HardCaml is an OCaml library for designing Register Transfer Level (RTL) hardware designs.  The current incarnation of the library allows hardware designs to be written and simulated in OCaml then converted into either VHDL or Verilog for synthesis.

# %% [markdown]
# ## Installation

# %% [markdown]
# `$ opam install hardcaml`
#
# This will install two ocamlfind packages; `hardcaml` and the syntax extension `hardcaml.syntax`.

# %% [markdown]
# ## Basic usage

# %% [markdown]
# With `utop`, `ocaml` or `iocaml`
#
# ```ocaml
# #use "topfind";;
# #require "hardcaml";;
# open HardCaml;;
# ```

# %% [markdown]
# A kernel for `iocamljs` is also provided and example notebooks (including this one) may be found on the [hardcaml website](https://andrewray.github.io/hardcaml).

# %% [markdown]
# ## Overview

# %% [markdown]
# The HardCaml API is designed around two main parts; combinatorial and sequential logic.  The combinatorial part provides operations such as bitwise XOR, addition, multiplexors etc.  The sequential part deals with registers and memories.
#
# Additionally the combinatorial API is implemented two ways - the so called shallow and deep embeddings.  The shallow embedding allows combinatoriall hardware structures to be evaluated immediately within the REPL.  The deep embedding constructs a cyclic graph of nodes that can be further processed to perform simulation or to generate netlists.

# %% [markdown]
# #### Shallow embedding

# %%
open HardCaml.Bits.Comb.IntbitsList

# %%
const "01" +: const "10"
# Out:
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">- : HardCaml.Bits.Comb.IntbitsList.t = [1; 1]
# </pre>

# %% [markdown]
# #### Deep embedding

# %%
open HardCaml.Signal.Comb

# %%
const "01" +: const "10"
# Out:
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">- : HardCaml.Signal.Comb.t = Signal_op[id:80 bits:2 names: deps:79,78] = add
#
# </pre>

# %% [markdown]
# #### Sequential logic

# %% [markdown]
# Sequential logic can only be described through the deep embedding

# %%
let print_signal fmt signal = Format.fprintf fmt "%s\n" (HardCaml.Signal.Comb.to_string signal);;
#install_printer print_signal;;
# Out:
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val print_signal : Format.formatter -&gt; HardCaml.Signal.Comb.t -&gt; unit = &lt;fun&gt;
# </pre>

# %%
open HardCaml.Signal.Comb
open HardCaml.Signal.Seq

# %%
let counter = 
  let d = wire 8 in
  let q = reg r_sync enable (d +:. 1) in
  let () = d <== q in
  q
# Out:
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val counter : HardCaml.Signal.Types.signal =
#   Signal_reg[id:86 bits:8 names: deps:83,3,0,85,1,5,84,1,6]
#
# </pre>

# %% [markdown]
# #### Going further with the deep embedding

# %% [markdown]
# The main purpose of the deep embedding is to perform some form of further processing.  Generally this is simulation, which will be convered in a later tutorial, or netlist generation.

# %%
let circuit = HardCaml.Circuit.make "counter" [ output "q" q ]
# Out:
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val circuit : HardCaml.Circuit.t =
#   {HardCaml.Circuit.circ_name = &quot;counter&quot;; circ_id_to_sig = &lt;abstr&gt;;
#    circ_inputs =
#     [Signal_wire[id:6 bits:1 names:enable deps:0] -&gt; 0
# ;
#      Signal_wire[id:5 bits:1 names:clear deps:0] -&gt; 0
# ;
#      Signal_wire[id:3 bits:1 names:clock deps:0] -&gt; 0
# ];
#    circ_outputs = [Signal_wire[id:87 bits:8 names:q deps:52] -&gt; 52
# ];
#    circ_fanout = &lt;abstr&gt;; circ_fanin = &lt;abstr&gt;}
# </pre>

# %%
HardCaml.Rtl.Verilog.write (output_string stdout) circuit
# Out:
# module counter (
#     enable,
#     clear,
#     clock,
#     q
# );
#     input enable;
#     input clear;
#     input clock;
#     output [7:0] q;
#     /* signal declarations */
#     wire [7:0] _50 = 8'b00000000;
#     wire vdd = 1'b1;
#     wire [7:0] _51 = 8'b00000000;
#     wire [7:0] _48 = 8'b00000001;
#     wire [7:0] _47;
#     wire [7:0] _49;
#     reg [7:0] _52;
#     /* logic */
#     assign _47 = _52;
#     assign _49 = _47 + _48;
#     always @(posedge clock) begin
#         if (clear)
#             _52 <= _50;
#         else
#             if (enable)
#                 _52 <= _49;
#     end
#     /* aliases */
#     /* output assignments */
#     assign q = _52;
# endmodule
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">- : unit = &lt;unknown constructor&gt;
# </pre>

# %% [markdown]
# #### Transformation

# %% [markdown]
# Now for a bit of fun we'll transform the circuit into something quite different.

# %%
module X = HardCaml.Xilinx.XSynthesize(HardCaml.Xilinx.Unisim)(HardCaml.Xilinx.Lut4)
let circuit = HardCaml.Transform.rewrite_circuit X.transform circuit
# Out:
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">module X : sig val transform : HardCaml.Transform.transform_fn end
# </pre>
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val circuit : HardCaml.Circuit.t =
#   {HardCaml.Circuit.circ_name = &quot;counter&quot;; circ_id_to_sig = &lt;abstr&gt;;
#    circ_inputs =
#     [Signal_wire[id:96 bits:1 names:enable deps:0] -&gt; 0
# ;
#      Signal_wire[id:95 bits:1 names:clear deps:0] -&gt; 0
# ;
#      Signal_wire[id:94 bits:1 names:clock deps:0] -&gt; 0
# ];
#    circ_outputs = [Signal_wire[id:98 bits:8 names:q deps:294] -&gt; 294
# ];
#    circ_fanout = &lt;abstr&gt;; circ_fanin = &lt;abstr&gt;}
# </pre>

# %%
HardCaml.Rtl.Verilog.write (output_string stdout) circuit
# Out:
# module counter (
#     enable,
#     clear,
#     clock,
#     q
# );
#     input enable;
#     input clear;
#     input clock;
#     output [7:0] q;
#     /* signal declarations */
#     wire _270;
#     wire _279;
#     wire _271;
#     wire _281;
#     wire _272;
#     wire _283;
#     wire _273;
#     wire _285;
#     wire _274;
#     wire _287;
#     wire _275;
#     wire _289;
#     wire _276;
#     wire _291;
#     wire _261;
#     wire _260;
#     wire _192;
#     wire [1:0] _257;
#     wire _193;
#     wire [2:0] _258;
#     wire _259;
#     wire _263;
#     wire _254;
#     wire _253;
#     wire _194;
#     wire [1:0] _250;
#     wire _195;
#     wire [2:0] _251;
#     wire _252;
#     wire _256;
#     wire _247;
#     wire _246;
#     wire _196;
#     wire [1:0] _243;
#     wire _197;
#     wire [2:0] _244;
#     wire _245;
#     wire _249;
#     wire _240;
#     wire _239;
#     wire _198;
#     wire [1:0] _236;
#     wire _199;
#     wire [2:0] _237;
#     wire _238;
#     wire _242;
#     wire _233;
#     wire _232;
#     wire _200;
#     wire [1:0] _229;
#     wire _201;
#     wire [2:0] _230;
#     wire _231;
#     wire _235;
#     wire _226;
#     wire _225;
#     wire _202;
#     wire [1:0] _222;
#     wire _203;
#     wire [2:0] _223;
#     wire _224;
#     wire _228;
#     wire _219;
#     wire _218;
#     wire _204;
#     wire [1:0] _215;
#     wire _205;
#     wire [2:0] _216;
#     wire _217;
#     wire _221;
#     wire _212;
#     wire _211;
#     wire _123;
#     wire _132;
#     wire _141;
#     wire _150;
#     wire _159;
#     wire _168;
#     wire _177;
#     wire _182;
#     wire _108;
#     wire _116;
#     wire [1:0] _180;
#     wire _181;
#     wire _184;
#     wire _173;
#     wire _115;
#     wire [1:0] _171;
#     wire _172;
#     wire _175;
#     wire _107;
#     wire _164;
#     wire _114;
#     wire [1:0] _162;
#     wire _163;
#     wire _166;
#     wire _106;
#     wire _155;
#     wire _113;
#     wire [1:0] _153;
#     wire _154;
#     wire _157;
#     wire _105;
#     wire _146;
#     wire _112;
#     wire [1:0] _144;
#     wire _145;
#     wire _148;
#     wire _104;
#     wire _137;
#     wire _111;
#     wire [1:0] _135;
#     wire _136;
#     wire _139;
#     wire _103;
#     wire _128;
#     wire _110;
#     wire [1:0] _126;
#     wire _127;
#     wire _130;
#     wire _102;
#     wire _119;
#     wire [7:0] _97;
#     wire _109;
#     wire [1:0] _117;
#     wire _118;
#     wire _121;
#     wire [7:0] _100 = 8'b00000001;
#     wire _101;
#     wire gnd = 1'b0;
#     wire _125;
#     wire _134;
#     wire _143;
#     wire _152;
#     wire _161;
#     wire _170;
#     wire _179;
#     wire _186;
#     wire [7:0] _189;
#     wire _206;
#     wire [1:0] _208;
#     wire [7:0] _190 = 8'b00000000;
#     wire _207;
#     wire [2:0] _209;
#     wire _210;
#     wire _214;
#     wire [7:0] _264;
#     wire _277;
#     wire gnd_0 = 1'b0;
#     wire _267;
#     wire [1:0] _265;
#     wire _266;
#     wire _269;
#     wire _293;
#     wire [7:0] _294;
#     /* logic */
#     assign _270 = _264[0:0];
#     FDCE
#         #( .INIT("0") )
#         the_FDCE
#         ( .C(clock), .CE(_269), .CLR(gnd_0), .D(_270), .Q(_279[0:0]) );
#     assign _271 = _264[1:1];
#     FDCE
#         #( .INIT("0") )
#         the_FDCE_0
#         ( .C(clock), .CE(_269), .CLR(gnd_0), .D(_271), .Q(_281[0:0]) );
#     assign _272 = _264[2:2];
#     FDCE
#         #( .INIT("0") )
#         the_FDCE_1
#         ( .C(clock), .CE(_269), .CLR(gnd_0), .D(_272), .Q(_283[0:0]) );
#     assign _273 = _264[3:3];
#     FDCE
#         #( .INIT("0") )
#         the_FDCE_2
#         ( .C(clock), .CE(_269), .CLR(gnd_0), .D(_273), .Q(_285[0:0]) );
#     assign _274 = _264[4:4];
#     FDCE
#         #( .INIT("0") )
#         the_FDCE_3
#         ( .C(clock), .CE(_269), .CLR(gnd_0), .D(_274), .Q(_287[0:0]) );
#     assign _275 = _264[5:5];
#     FDCE
#         #( .INIT("0") )
#         the_FDCE_4
#         ( .C(clock), .CE(_269), .CLR(gnd_0), .D(_275), .Q(_289[0:0]) );
#     assign _276 = _264[6:6];
#     FDCE
#         #( .INIT("0") )
#         the_FDCE_5
#         ( .C(clock), .CE(_269), .CLR(gnd_0), .D(_276), .Q(_291[0:0]) );
#     assign _261 = _258[2:2];
#     assign _260 = _258[1:1];
#     assign _192 = _189[0:0];
#     assign _257 = { _192, clear };
#     assign _193 = _190[0:0];
#     assign _258 = { _193, _257 };
#     assign _259 = _258[0:0];
#     LUT3
#         #( .INIT("00100111") )
#         the_LUT3
#         ( .I0(_259), .I1(_260), .I2(_261), .O(_263[0:0]) );
#     assign _254 = _251[2:2];
#     assign _253 = _251[1:1];
#     assign _194 = _189[1:1];
#     assign _250 = { _194, clear };
#     assign _195 = _190[1:1];
#     assign _251 = { _195, _250 };
#     assign _252 = _251[0:0];
#     LUT3
#         #( .INIT("00100111") )
#         the_LUT3_0
#         ( .I0(_252), .I1(_253), .I2(_254), .O(_256[0:0]) );
#     assign _247 = _244[2:2];
#     assign _246 = _244[1:1];
#     assign _196 = _189[2:2];
#     assign _243 = { _196, clear };
#     assign _197 = _190[2:2];
#     assign _244 = { _197, _243 };
#     assign _245 = _244[0:0];
#     LUT3
#         #( .INIT("00100111") )
#         the_LUT3_1
#         ( .I0(_245), .I1(_246), .I2(_247), .O(_249[0:0]) );
#     assign _240 = _237[2:2];
#     assign _239 = _237[1:1];
#     assign _198 = _189[3:3];
#     assign _236 = { _198, clear };
#     assign _199 = _190[3:3];
#     assign _237 = { _199, _236 };
#     assign _238 = _237[0:0];
#     LUT3
#         #( .INIT("00100111") )
#         the_LUT3_2
#         ( .I0(_238), .I1(_239), .I2(_240), .O(_242[0:0]) );
#     assign _233 = _230[2:2];
#     assign _232 = _230[1:1];
#     assign _200 = _189[4:4];
#     assign _229 = { _200, clear };
#     assign _201 = _190[4:4];
#     assign _230 = { _201, _229 };
#     assign _231 = _230[0:0];
#     LUT3
#         #( .INIT("00100111") )
#         the_LUT3_3
#         ( .I0(_231), .I1(_232), .I2(_233), .O(_235[0:0]) );
#     assign _226 = _223[2:2];
#     assign _225 = _223[1:1];
#     assign _202 = _189[5:5];
#     assign _222 = { _202, clear };
#     assign _203 = _190[5:5];
#     assign _223 = { _203, _222 };
#     assign _224 = _223[0:0];
#     LUT3
#         #( .INIT("00100111") )
#         the_LUT3_4
#         ( .I0(_224), .I1(_225), .I2(_226), .O(_228[0:0]) );
#     assign _219 = _216[2:2];
#     assign _218 = _216[1:1];
#     assign _204 = _189[6:6];
#     assign _215 = { _204, clear };
#     assign _205 = _190[6:6];
#     assign _216 = { _205, _215 };
#     assign _217 = _216[0:0];
#     LUT3
#         #( .INIT("00100111") )
#         the_LUT3_5
#         ( .I0(_217), .I1(_218), .I2(_219), .O(_221[0:0]) );
#     assign _212 = _209[2:2];
#     assign _211 = _209[1:1];
#     XORCY
#         the_XORCY
#         ( .CI(gnd), .LI(_121), .O(_123[0:0]) );
#     XORCY
#         the_XORCY_0
#         ( .CI(_125), .LI(_130), .O(_132[0:0]) );
#     XORCY
#         the_XORCY_1
#         ( .CI(_134), .LI(_139), .O(_141[0:0]) );
#     XORCY
#         the_XORCY_2
#         ( .CI(_143), .LI(_148), .O(_150[0:0]) );
#     XORCY
#         the_XORCY_3
#         ( .CI(_152), .LI(_157), .O(_159[0:0]) );
#     XORCY
#         the_XORCY_4
#         ( .CI(_161), .LI(_166), .O(_168[0:0]) );
#     XORCY
#         the_XORCY_5
#         ( .CI(_170), .LI(_175), .O(_177[0:0]) );
#     assign _182 = _180[1:1];
#     assign _108 = _100[7:7];
#     assign _116 = _97[7:7];
#     assign _180 = { _116, _108 };
#     assign _181 = _180[0:0];
#     LUT2
#         #( .INIT("0110") )
#         the_LUT2
#         ( .I0(_181), .I1(_182), .O(_184[0:0]) );
#     assign _173 = _171[1:1];
#     assign _115 = _97[6:6];
#     assign _171 = { _115, _107 };
#     assign _172 = _171[0:0];
#     LUT2
#         #( .INIT("0110") )
#         the_LUT2_0
#         ( .I0(_172), .I1(_173), .O(_175[0:0]) );
#     assign _107 = _100[6:6];
#     assign _164 = _162[1:1];
#     assign _114 = _97[5:5];
#     assign _162 = { _114, _106 };
#     assign _163 = _162[0:0];
#     LUT2
#         #( .INIT("0110") )
#         the_LUT2_1
#         ( .I0(_163), .I1(_164), .O(_166[0:0]) );
#     assign _106 = _100[5:5];
#     assign _155 = _153[1:1];
#     assign _113 = _97[4:4];
#     assign _153 = { _113, _105 };
#     assign _154 = _153[0:0];
#     LUT2
#         #( .INIT("0110") )
#         the_LUT2_2
#         ( .I0(_154), .I1(_155), .O(_157[0:0]) );
#     assign _105 = _100[4:4];
#     assign _146 = _144[1:1];
#     assign _112 = _97[3:3];
#     assign _144 = { _112, _104 };
#     assign _145 = _144[0:0];
#     LUT2
#         #( .INIT("0110") )
#         the_LUT2_3
#         ( .I0(_145), .I1(_146), .O(_148[0:0]) );
#     assign _104 = _100[3:3];
#     assign _137 = _135[1:1];
#     assign _111 = _97[2:2];
#     assign _135 = { _111, _103 };
#     assign _136 = _135[0:0];
#     LUT2
#         #( .INIT("0110") )
#         the_LUT2_4
#         ( .I0(_136), .I1(_137), .O(_139[0:0]) );
#     assign _103 = _100[2:2];
#     assign _128 = _126[1:1];
#     assign _110 = _97[1:1];
#     assign _126 = { _110, _102 };
#     assign _127 = _126[0:0];
#     LUT2
#         #( .INIT("0110") )
#         the_LUT2_5
#         ( .I0(_127), .I1(_128), .O(_130[0:0]) );
#     assign _102 = _100[1:1];
#     assign _119 = _117[1:1];
#     assign _97 = _294;
#     assign _109 = _97[0:0];
#     assign _117 = { _109, _101 };
#     assign _118 = _117[0:0];
#     LUT2
#         #( .INIT("0110") )
#         the_LUT2_6
#         ( .I0(_118), .I1(_119), .O(_121[0:0]) );
#     assign _101 = _100[0:0];
#     MUXCY
#         the_MUXCY
#         ( .CI(gnd), .DI(_101), .S(_121), .O(_125[0:0]) );
#     MUXCY
#         the_MUXCY_0
#         ( .CI(_125), .DI(_102), .S(_130), .O(_134[0:0]) );
#     MUXCY
#         the_MUXCY_1
#         ( .CI(_134), .DI(_103), .S(_139), .O(_143[0:0]) );
#     MUXCY
#         the_MUXCY_2
#         ( .CI(_143), .DI(_104), .S(_148), .O(_152[0:0]) );
#     MUXCY
#         the_MUXCY_3
#         ( .CI(_152), .DI(_105), .S(_157), .O(_161[0:0]) );
#     MUXCY
#         the_MUXCY_4
#         ( .CI(_161), .DI(_106), .S(_166), .O(_170[0:0]) );
#     MUXCY
#         the_MUXCY_5
#         ( .CI(_170), .DI(_107), .S(_175), .O(_179[0:0]) );
#     XORCY
#         the_XORCY_6
#         ( .CI(_179), .LI(_184), .O(_186[0:0]) );
#     assign _189 = { _186, _177, _168, _159, _150, _141, _132, _123 };
#     assign _206 = _189[7:7];
#     assign _208 = { _206, clear };
#     assign _207 = _190[7:7];
#     assign _209 = { _207, _208 };
#     assign _210 = _209[0:0];
#     LUT3
#         #( .INIT("00100111") )
#         the_LUT3_6
#         ( .I0(_210), .I1(_211), .I2(_212), .O(_214[0:0]) );
#     assign _264 = { _214, _221, _228, _235, _242, _249, _256, _263 };
#     assign _277 = _264[7:7];
#     assign _267 = _265[1:1];
#     assign _265 = { clear, enable };
#     assign _266 = _265[0:0];
#     LUT2
#         #( .INIT("0111") )
#         the_LUT2_7
#         ( .I0(_266), .I1(_267), .O(_269[0:0]) );
#     FDCE
#         #( .INIT("0") )
#         the_FDCE_6
#         ( .C(clock), .CE(_269), .CLR(gnd_0), .D(_277), .Q(_293[0:0]) );
#     assign _294 = { _293, _291, _289, _287, _285, _283, _281, _279 };
#     /* aliases */
#     /* output assignments */
#     assign q = _294;
# endmodule
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">- : unit = &lt;unknown constructor&gt;
# </pre>

# %% [markdown]
# The above code used the Xilinx module to transform the original RTL into the low level primtives provided on Xilinx FPGAs.  If this was written as an EDIF instead of verilog we would call it a synthesized netlist.
